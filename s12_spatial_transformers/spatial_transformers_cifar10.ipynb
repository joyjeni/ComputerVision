# %%
from __future__ import print_function
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
from torchvision import datasets, transforms
import matplotlib.pyplot as plt
import numpy as np

plt.ion()   # interactive mode

# %%
transform = transforms.Compose([
    transforms.Pad(4),
    transforms.RandomHorizontalFlip(),
    transforms.RandomCrop(32),
    transforms.ToTensor()])

# %%
def calculate_mean_std(dataset):
    if dataset == 'CIFAR10':
        train_transform = transforms
        train_set = datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
        mean = train_set.data.mean(axis=(0,1,2))/255
        std = train_set.data.std(axis=(0,1,2))/255
        return mean, std
mean,std = calculate_mean_std('CIFAR10')
# Out:
# Files already downloaded and verified

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Training dataset
train_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10(root='.', train=True, download=True,
                   transform=transforms.Compose([
                       transforms.ToTensor(),
                       transforms.Normalize((0.49139968, 0.48215841, 0.44653091),(0.24703223, 0.24348513, 0.26158784))
                   ])), batch_size=64, shuffle=True, num_workers=4)
# Test dataset
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10(root='.', train=False, transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2470, 0.2434, 0.2615))
    ])), batch_size=64, shuffle=True, num_workers=4)
# Out:
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, kernel_size=5)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(32*5*5, 1024)
        self.fc2 = nn.Linear(1024, 10)

        # Spatial transformer localization-network
        self.localization = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True),
            nn.Conv2d(64, 128, kernel_size=5),
            nn.MaxPool2d(2, stride=2),
            nn.ReLU(True)
        )

        # Regressor for the 3 * 2 affine matrix
        self.fc_loc = nn.Sequential(
            nn.Linear(128 * 4 * 4, 256),
            nn.ReLU(True),
            nn.Linear(256, 3 * 2)
        )

        # Initialize the weights/bias with identity transformation
        self.fc_loc[2].weight.data.zero_()
        self.fc_loc[2].bias.data.copy_(torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float))

    # Spatial transformer network forward function
    def stn(self, x):
        xs = self.localization(x)
        xs = xs.view(-1, xs.size(1) * xs.size(2) * xs.size(3))
        theta = self.fc_loc(xs)
        theta = theta.view(-1, 2, 3)

        grid = F.affine_grid(theta, x.size())
        x = F.grid_sample(x, grid)

        return x

    def forward(self, x):
        # transform the input
        x = self.stn(x)

        # Perform the usual forward pass
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 32*5*5)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %%
# initialize the model
model = Net().to(device)

# initialize the optimizer
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 16, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2_drop): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=800, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=10, bias=True)
#   (localization): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#   )
#   (fc_loc): Sequential(
#     (0): Linear(in_features=2048, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=256, out_features=6, bias=True)
#   )
# )

# %%
def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 500 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item()))

# %%
def test():
    with torch.no_grad():
        model.eval()
        test_loss = 0
        correct = 0
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)

            # sum up batch loss
            test_loss += F.nll_loss(output, target, size_average=False).item()
            # get the index of the max log-probability
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()

        test_loss /= len(test_loader.dataset)
        print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'
              .format(test_loss, correct, len(test_loader.dataset),
                      100. * correct / len(test_loader.dataset)))

# %%
def convert_image_np(inp):
    """Convert a Tensor to numpy image."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.49139968, 0.48215841, 0.44653091])
    std = np.array([0.24703223, 0.24348513, 0.26158784])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    return inp

# %%
def visualize_stn():
    with torch.no_grad():
        # Get a batch of training data
        data = next(iter(test_loader))[0].to(device)

        input_tensor = data.cpu()
        transformed_input_tensor = model.stn(data).cpu()

        in_grid = convert_image_np(
            torchvision.utils.make_grid(input_tensor))

        out_grid = convert_image_np(
            torchvision.utils.make_grid(transformed_input_tensor))

        # Plot the results side-by-side
        f, axarr = plt.subplots(1, 2,figsize=(20,15))
        # f = plt.figure(figsize=(20,15))
        axarr[0].imshow(in_grid)
        axarr[0].set_title('Dataset Images')

        axarr[1].imshow(out_grid)
        axarr[1].set_title('Transformed Images')

# %%
for epoch in range(1, 51):
    train(epoch)
    test()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:4044: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3982: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.332672
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 1.980878
# /usr/local/lib/python3.7/dist-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Average loss: 1.8327, Accuracy: 3371/10000 (34%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.994161
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 1.642029
#
# Test set: Average loss: 1.6402, Accuracy: 4158/10000 (42%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.775918
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 1.747083
#
# Test set: Average loss: 1.4910, Accuracy: 4572/10000 (46%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.491757
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 1.867864
#
# Test set: Average loss: 1.4731, Accuracy: 4709/10000 (47%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.497391
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 1.528320
#
# Test set: Average loss: 1.4619, Accuracy: 4649/10000 (46%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.980796
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 1.495412
#
# Test set: Average loss: 1.4566, Accuracy: 4812/10000 (48%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.790083
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 1.371613
#
# Test set: Average loss: 1.3167, Accuracy: 5312/10000 (53%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.396265
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 1.429091
#
# Test set: Average loss: 1.2716, Accuracy: 5545/10000 (55%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.398614
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 1.110618
#
# Test set: Average loss: 1.2329, Accuracy: 5695/10000 (57%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.404669
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 1.271993
#
# Test set: Average loss: 1.4545, Accuracy: 4839/10000 (48%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 1.445418
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 1.098092
#
# Test set: Average loss: 1.1873, Accuracy: 5873/10000 (59%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.550620
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 1.440295
#
# Test set: Average loss: 1.2036, Accuracy: 5823/10000 (58%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.098243
# Train Epoch: 13 [32000/50000 (64%)]	Loss: 1.218074
#
# Test set: Average loss: 1.1681, Accuracy: 5921/10000 (59%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 1.439458
# Train Epoch: 14 [32000/50000 (64%)]	Loss: 0.898162
#
# Test set: Average loss: 1.2328, Accuracy: 5788/10000 (58%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 1.362833
# Train Epoch: 15 [32000/50000 (64%)]	Loss: 1.197991
#
# Test set: Average loss: 1.1330, Accuracy: 6111/10000 (61%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.422035
# Train Epoch: 16 [32000/50000 (64%)]	Loss: 1.202299
#
# Test set: Average loss: 1.0820, Accuracy: 6282/10000 (63%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.052386
# Train Epoch: 17 [32000/50000 (64%)]	Loss: 1.174218
#
# Test set: Average loss: 1.0848, Accuracy: 6326/10000 (63%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 1.093039
# Train Epoch: 18 [32000/50000 (64%)]	Loss: 1.263875
#
# Test set: Average loss: 1.1576, Accuracy: 6095/10000 (61%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 1.215756
# Train Epoch: 19 [32000/50000 (64%)]	Loss: 0.921886
#
# Test set: Average loss: 1.0648, Accuracy: 6342/10000 (63%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 1.068055
# Train Epoch: 20 [32000/50000 (64%)]	Loss: 1.303374
#
# Test set: Average loss: 1.0534, Accuracy: 6412/10000 (64%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.959601
# Train Epoch: 21 [32000/50000 (64%)]	Loss: 0.921680
#
# Test set: Average loss: 1.0541, Accuracy: 6404/10000 (64%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 1.104453
# Train Epoch: 22 [32000/50000 (64%)]	Loss: 0.956066
#
# Test set: Average loss: 1.0465, Accuracy: 6387/10000 (64%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 1.077335
# Train Epoch: 23 [32000/50000 (64%)]	Loss: 0.782781
#
# Test set: Average loss: 1.0276, Accuracy: 6461/10000 (65%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.867504
# Train Epoch: 24 [32000/50000 (64%)]	Loss: 0.865364
#
# Test set: Average loss: 1.0329, Accuracy: 6455/10000 (65%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 1.182207
# Train Epoch: 25 [32000/50000 (64%)]	Loss: 1.020047
#
# Test set: Average loss: 1.0733, Accuracy: 6342/10000 (63%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 1.067850
# Train Epoch: 26 [32000/50000 (64%)]	Loss: 0.961196
#
# Test set: Average loss: 1.0929, Accuracy: 6212/10000 (62%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.851421
# Train Epoch: 27 [32000/50000 (64%)]	Loss: 0.995694
#
# Test set: Average loss: 1.0185, Accuracy: 6521/10000 (65%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.984448
# Train Epoch: 28 [32000/50000 (64%)]	Loss: 0.949449
#
# Test set: Average loss: 1.0651, Accuracy: 6345/10000 (63%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.893601
# Train Epoch: 29 [32000/50000 (64%)]	Loss: 0.958180
#
# Test set: Average loss: 1.0502, Accuracy: 6418/10000 (64%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.733262
# Train Epoch: 30 [32000/50000 (64%)]	Loss: 0.883126
#
# Test set: Average loss: 1.0352, Accuracy: 6464/10000 (65%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.790628
# Train Epoch: 31 [32000/50000 (64%)]	Loss: 0.985442
#
# Test set: Average loss: 1.0074, Accuracy: 6590/10000 (66%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.805863
# Train Epoch: 32 [32000/50000 (64%)]	Loss: 0.573542
#
# Test set: Average loss: 1.0379, Accuracy: 6426/10000 (64%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.841486
# Train Epoch: 33 [32000/50000 (64%)]	Loss: 0.917364
#
# Test set: Average loss: 1.0062, Accuracy: 6541/10000 (65%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.784087
# Train Epoch: 34 [32000/50000 (64%)]	Loss: 0.725344
#
# Test set: Average loss: 1.0533, Accuracy: 6412/10000 (64%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.829463
# Train Epoch: 35 [32000/50000 (64%)]	Loss: 0.867882
#
# Test set: Average loss: 1.0410, Accuracy: 6411/10000 (64%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.767157
# Train Epoch: 36 [32000/50000 (64%)]	Loss: 0.702033
#
# Test set: Average loss: 1.0696, Accuracy: 6324/10000 (63%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 1.026107
# Train Epoch: 37 [32000/50000 (64%)]	Loss: 0.714524
#
# Test set: Average loss: 1.0063, Accuracy: 6570/10000 (66%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.820632
# Train Epoch: 38 [32000/50000 (64%)]	Loss: 0.650899
#
# Test set: Average loss: 1.0626, Accuracy: 6387/10000 (64%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.987403
# Train Epoch: 39 [32000/50000 (64%)]	Loss: 1.056705
#
# Test set: Average loss: 1.0829, Accuracy: 6344/10000 (63%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.843949
# Train Epoch: 40 [32000/50000 (64%)]	Loss: 0.833345
#
# Test set: Average loss: 1.0771, Accuracy: 6345/10000 (63%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.855143
# Train Epoch: 41 [32000/50000 (64%)]	Loss: 0.638499
#
# Test set: Average loss: 0.9912, Accuracy: 6627/10000 (66%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.466581
# Train Epoch: 42 [32000/50000 (64%)]	Loss: 0.779908
#
# Test set: Average loss: 1.0465, Accuracy: 6398/10000 (64%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.911360
# Train Epoch: 43 [32000/50000 (64%)]	Loss: 0.723282
#
# Test set: Average loss: 1.0541, Accuracy: 6461/10000 (65%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.729420
# Train Epoch: 44 [32000/50000 (64%)]	Loss: 0.839568
#
# Test set: Average loss: 1.0340, Accuracy: 6534/10000 (65%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.777460
# Train Epoch: 45 [32000/50000 (64%)]	Loss: 0.835286
#
# Test set: Average loss: 1.0092, Accuracy: 6588/10000 (66%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.834507
# Train Epoch: 46 [32000/50000 (64%)]	Loss: 0.623226
#
# Test set: Average loss: 1.1327, Accuracy: 6093/10000 (61%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 1.079961
# Train Epoch: 47 [32000/50000 (64%)]	Loss: 0.770997
#
# Test set: Average loss: 0.9814, Accuracy: 6700/10000 (67%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.593139
# Train Epoch: 48 [32000/50000 (64%)]	Loss: 1.029358
#
# Test set: Average loss: 1.0796, Accuracy: 6416/10000 (64%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.612050
# Train Epoch: 49 [32000/50000 (64%)]	Loss: 0.789765
#
# Test set: Average loss: 1.0704, Accuracy: 6393/10000 (64%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.591832
# Train Epoch: 50 [32000/50000 (64%)]	Loss: 0.837496
#
# Test set: Average loss: 1.0165, Accuracy: 6638/10000 (66%)

# %%
visualize_stn()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:4044: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3982: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   "Default grid_sample and affine_grid behavior has changed "
